# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = 'data/data.csv'
df = pd.read_csv(file_path)

# Display first few rows
df.head()
# Out:
#              timestamp equipment_energy_consumption     lighting_energy  \
# 0  2016-01-11 17:00:00                         60.0  -77.78778596503064
# 1  2016-01-11 17:10:00                         60.0                30.0
# 2  2016-01-11 17:20:00                         50.0                30.0
# 3  2016-01-11 17:30:00                         50.0                40.0
# 4  2016-01-11 17:40:00                         60.0                40.0
#
#    zone1_temperature     zone1_humidity zone2_temperature  zone2_humidity  \
# 0  33.74660933896648  47.59666666666671              19.2       44.790000
# 1              19.89  46.69333333333329              19.2       44.722500
# 2              19.89               46.3              19.2       44.626667
# 3  33.74660933896648   46.0666666666667              19.2       44.590000
# 4              19.89  46.33333333333329              19.2       44.530000
#
#    zone3_temperature  zone3_humidity  zone4_temperature  ...  \
# ...

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
# Check shape of the dataset
print("Dataset Shape:", df.shape)

# Display data types and non-null counts
df.info()

# Basic statistics
df.describe().T
# Out:
# Dataset Shape: (16857, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     16857 non-null  object
#  1   equipment_energy_consumption  16013 non-null  object
#  2   lighting_energy               16048 non-null  object
#  3   zone1_temperature             15990 non-null  object
#  4   zone1_humidity                16056 non-null  object
#  5   zone2_temperature             16004 non-null  object
#  6   zone2_humidity                15990 non-null  float64
#  7   zone3_temperature             16055 non-null  float64
#  8   zone3_humidity                15979 non-null  float64
#  9   zone4_temperature             16041 non-null  float64
#  10  zone4_humidity                16076 non-null  float64
#  11  zone5_temperature             16019 non-null  float64
# ...

# %%
# Convert all object columns (except timestamp) to numeric
for col in df.columns:
    if df[col].dtype == 'object' and col != 'timestamp':
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.duplicated().sum()
# Out:
# np.int64(68)

# %%
df = df.drop_duplicates()
print("After removing duplicates:", df.shape)
# Out:
# After removing duplicates: (16789, 29)

# %%
# Count missing values in each column
df.isnull().sum()
# Out:
# timestamp                         0
# equipment_energy_consumption    909
# lighting_energy                 861
# zone1_temperature               944
# zone1_humidity                  886
# zone2_temperature               918
# zone2_humidity                  863
# zone3_temperature               798
# zone3_humidity                  877
# zone4_temperature               811
# zone4_humidity                  775
# zone5_temperature               832
# zone5_humidity                  797
# zone6_temperature               842
# zone6_humidity                  841
# zone7_temperature               787
# zone7_humidity                  800
# zone8_temperature               843
# zone8_humidity                  776
# zone9_temperature               771
# zone9_humidity                  886
# outdoor_temperature             802
# atmospheric_pressure            841
# outdoor_humidity                794
# wind_speed                      822
# visibility_index                809
# ...

# %%
# Fill remaining missing values with column-wise mean
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
# Confirm no missing values remain
print(df.isnull().sum().sum())
# Out:
# 0

# %%
df.head()
# Out:
#              timestamp  equipment_energy_consumption  lighting_energy  \
# 0  2016-01-11 17:00:00                          60.0       -77.787786
# 1  2016-01-11 17:10:00                          60.0        30.000000
# 2  2016-01-11 17:20:00                          50.0        30.000000
# 3  2016-01-11 17:30:00                          50.0        40.000000
# 4  2016-01-11 17:40:00                          60.0        40.000000
#
#    zone1_temperature  zone1_humidity  zone2_temperature  zone2_humidity  \
# 0          33.746609       47.596667               19.2       44.790000
# 1          19.890000       46.693333               19.2       44.722500
# 2          19.890000       46.300000               19.2       44.626667
# 3          33.746609       46.066667               19.2       44.590000
# 4          19.890000       46.333333               19.2       44.530000
#
#    zone3_temperature  zone3_humidity  zone4_temperature  ...  \
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['equipment_energy_consumption'], kde=True, bins=50)
plt.title('Distribution of Equipment Energy Consumption')
plt.xlabel('Energy Consumption (Wh)')
plt.ylabel('Frequency')
plt.show()

# %%
# Remove rows with negative target values
df = df[df['equipment_energy_consumption'] >= 0]

# %%
# applying a log transformation to normalize the target variable
df['equipment_energy_consumption'] = np.log1p(df['equipment_energy_consumption'])

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['equipment_energy_consumption'], kde=True, bins=50)
plt.title('Distribution of Equipment Energy Consumption')
plt.xlabel('Energy Consumption (Wh)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

# %%
target_corr = corr_matrix['equipment_energy_consumption'].sort_values(ascending=False)
print(target_corr)
# Out:
# equipment_energy_consumption    1.000000
# lighting_energy                 0.124974
# zone2_temperature               0.105592
# zone3_temperature               0.095672
# zone1_temperature               0.090588
# outdoor_temperature             0.084512
# zone8_temperature               0.079271
# zone6_temperature               0.078861
# zone4_temperature               0.076501
# zone5_temperature               0.055867
# zone7_temperature               0.050330
# zone9_temperature               0.047781
# wind_speed                      0.033017
# zone1_humidity                  0.030540
# dew_point                       0.022409
# zone5_humidity                  0.020290
# zone3_humidity                  0.007903
# visibility_index                0.000677
# random_variable2               -0.009322
# random_variable1               -0.011370
# zone4_humidity                 -0.015943
# zone2_humidity                 -0.028261
# atmospheric_pressure           -0.035642
# ...

# %%
df[['random_variable1', 'random_variable2', 'equipment_energy_consumption']].corr()
# Out:
#                               random_variable1  random_variable2  \
# random_variable1                      1.000000          0.279058
# random_variable2                      0.279058          1.000000
# equipment_energy_consumption         -0.011370         -0.009322
#
#                               equipment_energy_consumption
# random_variable1                                 -0.011370
# random_variable2                                 -0.009322
# equipment_energy_consumption                      1.000000

# %% [markdown]
# # Data preprocessing steps

# %%
zone_cols = ['zone1_temperature', 'zone2_temperature', 'zone3_temperature']

for col in zone_cols:
    plt.figure(figsize=(8, 4))
    sns.scatterplot(data=df, x=col, y='equipment_energy_consumption', alpha=0.3)
    plt.title(f'Energy Consumption vs {col}')
    plt.grid(True)
    plt.show()

# %%
for col in ['zone1_temperature', 'zone2_temperature', 'zone3_temperature','zone4_temperature','zone5_temperature','zone6_temperature','zone7_temperature','zone8_temperature','zone9_temperature']:
    df = df[(df[col] >= 10) & (df[col] <= 30)]

# %%
zone_cols = ['zone1_humidity', 'zone2_humidity', 'zone3_humidity']

for col in zone_cols:
    plt.figure(figsize=(8, 4))
    sns.scatterplot(data=df, x=col, y='equipment_energy_consumption', alpha=0.3)
    plt.title(f'Energy Consumption vs {col}')
    plt.grid(True)
    plt.show()

# %%
for col in ['zone1_humidity', 'zone2_humidity', 'zone3_humidity', 'zone4_humidity','zone5_humidity', 'zone6_humidity', 'zone7_humidity', 'zone8_humidity', 'zone9_humidity']:
    df = df[(df[col] >= 0) & (df[col] <= 100)]

# %%
zone_cols = ['outdoor_temperature', 'outdoor_humidity', 'atmospheric_pressure']

for col in zone_cols:
    plt.figure(figsize=(8, 4))
    sns.scatterplot(data=df, x=col, y='equipment_energy_consumption', alpha=0.3)
    plt.title(f'Energy Consumption vs {col}')
    plt.grid(True)
    plt.show()

# %%
for col in ['outdoor_temperature']:
    df = df[(df[col] >= 0) & (df[col] <= 40)]

# %%
for col in ['outdoor_humidity']:
    df = df[(df[col] >= 0) & (df[col] <= 100)]

# %%
for col in ['atmospheric_pressure']:
    df = df[(df[col] >= 720) & (df[col] <= 800)]

# %%
zone_cols = ['wind_speed', 'visibility_index', 'dew_point']

for col in zone_cols:
    plt.figure(figsize=(8, 4))
    sns.scatterplot(data=df, x=col, y='equipment_energy_consumption', alpha=0.3)
    plt.title(f'Energy Consumption vs {col}')
    plt.grid(True)
    plt.show()

# %%
df = df[(df['wind_speed'] >= 0) & (df['wind_speed'] <= 15)]
df = df[(df['visibility_index'] >= 0) & (df['visibility_index'] <= 100)]
df = df[(df['dew_point'] >= -10) & (df['dew_point'] <= 25)]

# %%
zone_cols = ['random_variable1', 'random_variable2']

for col in zone_cols:
    plt.figure(figsize=(8, 4))
    sns.scatterplot(data=df, x=col, y='equipment_energy_consumption', alpha=0.3)
    plt.title(f'Energy Consumption vs {col}')
    plt.grid(True)
    plt.show()

# %%
df[['random_variable1', 'random_variable2', 'equipment_energy_consumption']].corr()
# Out:
#                               random_variable1  random_variable2  \
# random_variable1                      1.000000          0.262314
# random_variable2                      0.262314          1.000000
# equipment_energy_consumption         -0.013389         -0.019250
#
#                               equipment_energy_consumption
# random_variable1                                 -0.013389
# random_variable2                                 -0.019250
# equipment_energy_consumption                      1.000000

# %%
df = df[(df['random_variable1'] >= 0) & (df['random_variable1'] <= 50)]
#df = df[(df['random_variable2'] >= 0) & (df['random_variable2'] <= 50)]

# %%
zone_cols = ['lighting_energy']

for col in zone_cols:
    plt.figure(figsize=(8, 4))
    sns.scatterplot(data=df, x=col, y='equipment_energy_consumption', alpha=0.3)
    plt.title(f'Energy Consumption vs {col}')
    plt.grid(True)
    plt.show()

# %%
df = df[df['lighting_energy'] >= 0]

# %%
plt.figure(figsize=(12, 6))
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# # Feature engineering and selection

# %%
# Zone columns
zone_temp_cols = [f'zone{i}_temperature' for i in range(1, 10)]
zone_humid_cols = [f'zone{i}_humidity' for i in range(1, 10)]

# Aggregate zone statistics
df['mean_zone_temp'] = df[zone_temp_cols].mean(axis=1)
df['std_zone_temp'] = df[zone_temp_cols].std(axis=1)
df['min_zone_temp'] = df[zone_temp_cols].min(axis=1)
df['max_zone_temp'] = df[zone_temp_cols].max(axis=1)

df['mean_zone_humidity'] = df[zone_humid_cols].mean(axis=1)
df['std_zone_humidity'] = df[zone_humid_cols].std(axis=1)
df['min_zone_humidity'] = df[zone_humid_cols].min(axis=1)
df['max_zone_humidity'] = df[zone_humid_cols].max(axis=1)

# Thermal comfort index
df['temp_humidity_index'] = df['mean_zone_temp'] * df['mean_zone_humidity'] / 100

# Temporal features
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['hour'] = df['timestamp'].dt.hour
df['day_of_week'] = df['timestamp'].dt.dayofweek
df['month'] = df['timestamp'].dt.month
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

# %%
df.head()
# Out:
#                timestamp  equipment_energy_consumption  lighting_energy  \
# 1995 2016-01-25 12:20:00                      4.110874              0.0
# 1998 2016-01-25 12:50:00                      3.931826              0.0
# 2008 2016-01-25 14:30:00                      3.044522              0.0
# 2009 2016-01-25 14:40:00                      3.713572              0.0
# 2010 2016-01-25 14:50:00                      4.110874              0.0
#
#       zone1_temperature  zone1_humidity  zone2_temperature  zone2_humidity  \
# 1995          20.100000       43.900000          19.500000       43.200000
# 1998          20.200000       43.700000          19.500000       43.126667
# 2008          20.500000       43.326667          19.500000       39.488571
# 2009          20.600000       39.046351          19.533333       43.090000
# 2010          20.666667       43.200000          19.600000       43.090000
#
#       zone3_temperature  zone3_humidity  zone4_temperature  ...  \
# ...

# %% [markdown]
# # Model development and training

# %%
# Define target and feature matrix
target_col = 'equipment_energy_consumption'
feature_cols = [
    'lighting_energy', 'outdoor_temperature', 'wind_speed', 'dew_point', 'random_variable1',
    'mean_zone_temp', 'std_zone_temp', 'min_zone_temp', 'max_zone_temp',
    'mean_zone_humidity', 'std_zone_humidity', 'min_zone_humidity', 'max_zone_humidity',
    'temp_humidity_index', 'hour_sin', 'hour_cos', 'day_of_week', 'month'
]

X = df[feature_cols].copy()
y = df[target_col].copy()

X.head()
# Out:
#       lighting_energy  outdoor_temperature  wind_speed  dew_point  \
# 1995              0.0            12.066667    4.666667   3.766667
# 1998              0.0            12.016667    5.666667   4.166667
# 2008              0.0            12.900000    5.000000   4.200000
# 2009              0.0            12.966667    5.000000   4.233333
# 2010              0.0            13.033333    5.000000   4.266667
#
#       random_variable1  mean_zone_temp  std_zone_temp  min_zone_temp  \
# 1995         27.408876       17.547716       3.030148      10.166667
# 1998          8.302184       18.004170       2.897701      10.660000
# 2008         48.359852       18.419549       2.725156      11.800000
# 2009         43.345814       18.260679       2.636279      11.890000
# 2010         21.885765       18.323827       2.639527      11.963333
#
#       max_zone_temp  mean_zone_humidity  std_zone_humidity  min_zone_humidity  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Apply standard scaling to features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Reverse log transform
y_train_true = np.expm1(y_train)
y_test_true = np.expm1(y_test)
y_train_pred_true = np.expm1(y_train_pred)
y_test_pred_true = np.expm1(y_test_pred)

# Evaluation metrics
rmse_val = np.sqrt(mean_squared_error(y_train_true, y_train_pred_true))
mae_val = mean_absolute_error(y_train_true, y_train_pred_true)
r2_val = r2_score(y_train_true, y_train_pred_true)

rmse_test = np.sqrt(mean_squared_error(y_test_true, y_test_pred_true))
mae_test = mean_absolute_error(y_test_true, y_test_pred_true)
r2_test = r2_score(y_test_true, y_test_pred_true)

metrics = {
    'Validation RMSE': rmse_val,
    'Validation MAE': mae_val,
    'Validation R²': r2_val,
    'Test RMSE': rmse_test,
    'Test MAE': mae_test,
    'Test R²': r2_test
}

# Plot actual vs predicted (on original scale)
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test_true, y=y_test_pred_true, alpha=0.4)
plt.plot([y_test_true.min(), y_test_true.max()], [y_test_true.min(), y_test_true.max()], 'r--')
plt.xlabel("Actual Energy Consumption (Wh)")
plt.ylabel("Predicted Energy Consumption (Wh)")
plt.title("Actual vs Predicted Energy Consumption (Test Set)")
plt.grid(True)
plt.show()

# Plot: Residuals (on original scale)
plt.figure(figsize=(8, 6))
residuals = y_test_true - y_test_pred_true
sns.histplot(residuals, bins=50, kde=True)
plt.title("Residuals Distribution (Test Set)")
plt.xlabel("Prediction Error (Wh)")
plt.grid(True)
plt.show()

# Show evaluation metrics
pd.DataFrame([metrics])
# Out:
#    Validation RMSE  Validation MAE  Validation R²   Test RMSE   Test MAE  \
# 0        84.095386       27.141156       0.705709  113.567131  50.944151
#
#     Test R²
# 0  0.254725

# %%
# Re-import libraries after kernel reset
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import randint

# Hyperparameter tuning with RandomizedSearchCV
param_dist = {
    'n_estimators': randint(50, 150),
    'max_depth': randint(4, 15),
    'min_samples_split': randint(2, 8),
    'min_samples_leaf': randint(1, 6),
    'max_features': ['sqrt', 'log2', None] 
}


rf_base = RandomForestRegressor(random_state=42)

random_search = RandomizedSearchCV(
    estimator=rf_base,
    param_distributions=param_dist,
    n_iter=25,
    scoring='neg_root_mean_squared_error',
    cv=5,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_scaled, y)

best_rf_model = random_search.best_estimator_
best_params = random_search.best_params_
best_score = -random_search.best_score_

(best_params, best_score)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# ({'max_depth': 7,
#   'max_features': 'log2',
#   'min_samples_leaf': 4,
#   'min_samples_split': 3,
#   'n_estimators': 55},
#  np.float64(0.662934028858411))

# %%
# Re-import libraries after reset
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Clip log-transformed target if needed
y_clipped = np.clip(y, a_min=None, a_max=50)

# Define best Random Forest model
model = RandomForestRegressor(
    n_estimators=55,
    max_depth=7,
    max_features='log2',
    min_samples_leaf=4,
    min_samples_split=3,
    random_state=42
)

# Apply cross-validation
cv = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = -cross_val_score(model, X_scaled, y_clipped, cv=cv, scoring='neg_root_mean_squared_error')
cv_mae = -cross_val_score(model, X_scaled, y_clipped, cv=cv, scoring='neg_mean_absolute_error')
cv_r2 = cross_val_score(model, X_scaled, y_clipped, cv=cv, scoring='r2')

# Summarize cross-validation results
cv_results = {
    "CV RMSE Mean": np.mean(cv_rmse),
    "CV RMSE Std": np.std(cv_rmse),
    "CV MAE Mean": np.mean(cv_mae),
    "CV MAE Std": np.std(cv_mae),
    "CV R² Mean": np.mean(cv_r2),
    "CV R² Std": np.std(cv_r2)
}

pd.DataFrame([cv_results])
# Out:
#    CV RMSE Mean  CV RMSE Std  CV MAE Mean  CV MAE Std  CV R² Mean  CV R² Std
# 0      0.570196      0.02816     0.398574    0.014855    0.337072   0.040411

# %%
plt.figure(figsize=(12, 6))
corr_matrix = X.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()
